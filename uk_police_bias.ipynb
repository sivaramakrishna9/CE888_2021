# %%
#Step 1: Import packages and set the working directory

#The OS module in Python provides functions for interacting with the operating system. OS comes under Python's standard utility modules.
import os

#It retrieves the list of files matching the specified pattern in the file_pattern parameter.
#The recursive parameter is turn off (False) by default. When True, it recursively searches files under all subdirectories of the current directory.
import glob

#simply imports the library the current namespace, but rather than using the name pandas 
# mostly it used as pd
import pandas as pd

os.chdir("C:/Users/HP\Documents/888-2_29April/srk/2020-04")

# %%
#Step 2: Use glob to match the pattern ‘csv’
extension = 'csv'
all_filenames = [i for i in glob.glob('*.{}'.format(extension))]

# %%
#Step 3: Combine all files in the list and export as CSV
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv1.csv", index=False, encoding='utf-8-sig')

# %%
##Step 4:reading the combined csv file
df = pd.read_csv('combined_csv1.csv', delimiter='t', encoding='utf-8-sig')
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
##Step 5
print(df.shape)
# Out:
# (187056, 22)

# %%
#step 6
df = []
for filename in all_filenames:
    df.append(pd.read_csv(filename))

# %%
df
# Out:
# [                           Type                       Date  \
#  0                Vehicle search  2020-04-01T00:00:00+00:00
#  1     Person and Vehicle search  2020-04-01T00:15:00+00:00
#  2     Person and Vehicle search  2020-04-01T00:20:00+00:00
#  3     Person and Vehicle search  2020-04-01T00:25:00+00:00
#  4     Person and Vehicle search  2020-04-01T00:30:00+00:00
#  ...                         ...                        ...
#  1052              Person search  2020-04-30T21:20:00+00:00
#  1053              Person search  2020-04-30T21:20:00+00:00
#  1054              Person search  2020-04-30T21:20:00+00:00
#  1055              Person search  2020-04-30T21:20:00+00:00
#  1056  Person and Vehicle search  2020-04-30T22:55:00+00:00
#
#        Part of a policing operation  Policing operation   Latitude  Longitude  \
#  0                              NaN                 NaN        NaN        NaN
#  1                              NaN                 NaN  51.131042  -3.014055
# ...

# %%
#step8
#creating of the big frame from the data set we have used in the previous step
#this will display the headers in file
big_frame_df = pd.concat(df, ignore_index=True)
df = pd.DataFrame(big_frame)

# %%
df
# Out:
#                             Type                       Date  \
# 0                 Vehicle search  2020-04-01T00:00:00+00:00
# 1      Person and Vehicle search  2020-04-01T00:15:00+00:00
# 2      Person and Vehicle search  2020-04-01T00:20:00+00:00
# 3      Person and Vehicle search  2020-04-01T00:25:00+00:00
# 4      Person and Vehicle search  2020-04-01T00:30:00+00:00
# ...                          ...                        ...
# 62347  Person and Vehicle search  2020-04-29T23:00:00+00:00
# 62348              Person search  2020-04-29T23:00:00+00:00
# 62349  Person and Vehicle search  2020-04-29T23:00:00+00:00
# 62350  Person and Vehicle search  2020-04-29T23:00:00+00:00
# 62351  Person and Vehicle search  2020-04-29T23:00:00+00:00
#
#       Part of a policing operation  Policing operation   Latitude  Longitude  \
# 0                              NaN                 NaN        NaN        NaN
# 1                              NaN                 NaN  51.131042  -3.014055
# ...

# %%
#step 10
#Creating independent and dependend variables(in this case Self-defined ethnicity,Officer-defined ethnicity, Outcome are the 
# independent variable and remaining are the dependent variable)
#IDV = Independent variable
idv=pd.DataFrame()

# %%
# these will create another data frame for further clarification
idv["Self-defined ethnicity"]=df["Self-defined ethnicity"]
idv["Officer-defined ethnicity"]=df["Officer-defined ethnicity"]
idv["Outcome"]=df["Outcome"]

# %%
idv
# Out:
#                                   Self-defined ethnicity  \
# 0                                                    NaN
# 1      White - English/Welsh/Scottish/Northern Irish/...
# 2      White - English/Welsh/Scottish/Northern Irish/...
# 3      White - English/Welsh/Scottish/Northern Irish/...
# 4      White - English/Welsh/Scottish/Northern Irish/...
# ...                                                  ...
# 62347                    Other ethnic group - Not stated
# 62348  White - English/Welsh/Scottish/Northern Irish/...
# 62349  Black/African/Caribbean/Black British - Any ot...
# 62350  Black/African/Caribbean/Black British - Any ot...
# 62351  White - English/Welsh/Scottish/Northern Irish/...
#
#       Officer-defined ethnicity                          Outcome
# 0                           NaN                              NaN
# 1                         White         Khat or Cannabis warning
# 2                         White     A no further action disposal
# ...

# %%
#entering the data in to the empty cell (NaN)
ec1=df["Outcome"].fillna("A no further action disposal")
ec2=df["Officer-defined ethnicity"].fillna("White")
ec3=df["Self-defined ethnicity"].fillna("A no further action disposal")
ecf=pd.DataFrame()

# %%
ecf["Self-defined ethnicity"]=ec1
ecf["Officer-defined ethnicity"]=ec2
ecf["Outcome"]=ec3

# %%
ecf
# Out:
#                 Self-defined ethnicity Officer-defined ethnicity  \
# 0         A no further action disposal                     White
# 1             Khat or Cannabis warning                     White
# 2         A no further action disposal                     White
# 3         A no further action disposal                     White
# 4             Khat or Cannabis warning                     White
# ...                                ...                       ...
# 62347     A no further action disposal                     White
# 62348     A no further action disposal                     White
# 62349     A no further action disposal                     White
# 62350  Caution (simple or conditional)                     White
# 62351     A no further action disposal                     White
#
#                                                  Outcome
# 0                           A no further action disposal
# 1      White - English/Welsh/Scottish/Northern Irish/...
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 25))
ecf.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Officer-defined ethnicity'>

# %%
#creating groups based on the ethnic
ecf = ecf.groupby('Officer-defined ethnicity').count()

# %%
#printing the group
ecf
# Out:
#                            Self-defined ethnicity  Outcome
# Officer-defined ethnicity
# Asian                                        8395     8395
# Black                                       14490    14490
# Mixed                                         175      175
# Other                                        2048     2048
# White                                       37244    37244

# %%
#creating groups based on the ethnic
ecf = ecf.groupby('Self-defined ethnicity').count()

# %%
ecf
# Out:
#                         Outcome
# Self-defined ethnicity
# 1                             5

# %%
#creating groups based on the outcome
ecf = ecf.groupby('Outcome').count()

# %%
ecf
# Out:
# Empty DataFrame
# Columns: []
# Index: [5]
